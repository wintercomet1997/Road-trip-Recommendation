# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
d=pd.read_csv('training.csv')
d_test = pd.read_csv('testing.csv')
print(d_test)
#print(d)
# Out:
#     Place      Month  HighTemp  LowTemp  MeanTemp  Precipitation  Humidity  \
# 0   Udupi        Jan        33       21        27            0.6        65
# 1   Udupi        Feb        34       22        28            5.0        66
# 2   Udupi      March        34       24        29           21.7        71
# 3   Udupi      April        34       25        29           38.0        72
# 4   Udupi        May        33       25        29           87.7        76
# 5   Udupi       June        30       24        27          414.9        87
# 6   Udupi       July        29       23        26          485.2        89
# 7   Udupi     August        29       23        26          364.4        89
# 8   Udupi  September        30       23        27          275.5        86
# 9   Udupi    October        32       23        27          150.8        83
# 10  Udupi   November        33       23        28          109.6        75
# ...

# %%
feature_cols = ['HighTemp','LowTemp','MeanTemp','Precipitation','DewPoint','Wind','Pressure','Visibility']
X = d[feature_cols] # Features
y = d.SuitableForTravelling # Target variable
x_test = d_test[feature_cols]
y_test = d_test.SuitableForTravelling

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
# print(X_train)
# print(y_train)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X,y)

#Predict the response for test dataset
y_pred = clf.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9166666666666666

# %%
# new = d.loc[d['Place'] == 'Mysore']
# X = new[feature_cols]

# %%
# a = []
# y_pred = clf.predict(X)
# for i in range(len(y_pred)):
#     if y_pred[i] == 'Yes':
#         a.append(new['Month'].iloc[i])
# print(a)
# Out:
# ['Feb', 'June', 'October', 'November', 'December']

# %%
# testing = pd.read_csv('weather_dataset.csv')
# X = testing[feature_cols]
# a = []
# y_pred = clf.predict(X)
# for i in range(len(y_pred)):
#     if y_pred[i] == 'Yes':
#         a.append(testing['Month'].iloc[i])
# print(a)
# Out:
# ['Jan', 'Feb', 'June', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November', 'December', 'Feb', 'June', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November', 'December', 'Jan', 'Feb', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November', 'December', 'Jan', 'Feb', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November', 'December', 'Jan', 'Feb', 'June', 'October', 'November', 'December', 'Jan', 'Feb', 'June', 'October', 'November', 'December', 'Jan', 'Feb', 'June', 'October', 'November', 'December', 'Jan', 'Feb', 'June', 'July', 'October', 'November', 'December', 'Jan', 'Feb', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November', 'December', 'Jan', 'Feb', 'June', 'October', 'November', 'December', 'Jan', 'Feb', 'March', 'October', 'November'
# ...

# %%
# this is to print the decision tree
# from sklearn.tree import export_graphviz
# from sklearn.externals.six import StringIO  
# from IPython.display import Image

# %%
# import pydotplus

# %%
# dot_data = StringIO()
# export_graphviz(clf, out_file=dot_data,  
#                 filled=True, rounded=True,
#                 special_characters=True,feature_names = feature_cols,class_names=['Yes','No'])
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# graph.write_png('diabetes.png')
# Image(graph.create_png())

# %%
# print(testing)
# Out:
#                Place      Month  HighTemp  LowTemp  MeanTemp  Precipitation  \
# 0          Bangalore        Jan        29       16        23            1.0
# 1          Bangalore        Feb        31       18        24            7.5
# 2          Bangalore      March        33       20        27           22.6
# 3          Bangalore      April        34       22        28           85.6
# 4          Bangalore        May        33       22        27          124.8
# 5          Bangalore       June        30       21        25           94.8
# 6          Bangalore       July        29       20        24          138.3
# 7          Bangalore     August        28       20        24          170.0
# 8          Bangalore  September        29       20        24          176.6
# 9          Bangalore    October        29       20        24          116.9
# 10         Bangalore   November        28       18        23           79.2
# ...

# %%
# substitute district of the place that is selected to find the favorable months to travel 
new = testing.loc[testing['Place'] == 'Shimoga']
X = new[feature_cols]
a = []
y_pred = clf.predict(X)
for i in range(len(y_pred)):
    if y_pred[i] == 'Yes':
        a.append(new['Month'].iloc[i])
print(a)
# Out:
# ['Jan', 'Feb', 'March', 'October', 'November', 'December']
